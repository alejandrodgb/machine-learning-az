# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Data

# %% [markdown]
# ## Import

# %%
dataset = pd.read_csv('Position_Salaries.csv')
X = dataset.iloc[:,1:-1].values
y = dataset.iloc[:,-1].values

# %% [markdown]
# # Training

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
regressor = RandomForestRegressor(n_estimators=10,random_state=0)
regressor.fit(X,y)
# Out:
# RandomForestRegressor(n_estimators=10, random_state=0)

# %% [markdown]
# # Prediction

# %%
regressor.predict([[6.5]])
# Out:
# array([167000.])

# %% [markdown]
# # Visualisation

# %%
X_grid = np.arange(min(X),max(X),0.1).reshape(-1,1)
plt.scatter(X,y)
plt.plot(X_grid,regressor.predict(X_grid),color='r')
# Out:
# /var/folders/82/b18r5lg13lj0jsssnjzrfj780000gn/T/ipykernel_1347/3790152177.py:1: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   X_grid = np.arange(min(X),max(X),0.1).reshape(-1,1)
