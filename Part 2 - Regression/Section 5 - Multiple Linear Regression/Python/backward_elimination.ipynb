# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# # Data

# %% [markdown]
# ## Import

# %%
dataset = pd.read_csv('50_Startups.csv')
dataset.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
dataset.describe(include='all')
# Out:
#             R&D Spend  Administration  Marketing Spend     State  \
# count       50.000000       50.000000        50.000000        50
# unique            NaN             NaN              NaN         3
# top               NaN             NaN              NaN  New York
# freq              NaN             NaN              NaN        17
# mean     73721.615600   121344.639600    211025.097800       NaN
# std      45902.256482    28017.802755    122290.310726       NaN
# min          0.000000    51283.140000         0.000000       NaN
# 25%      39936.370000   103730.875000    129300.132500       NaN
# 50%      73051.080000   122699.795000    212716.240000       NaN
# 75%     101602.800000   144842.180000    299469.085000       NaN
# max     165349.200000   182645.560000    471784.100000       NaN
#
#                Profit
# count       50.000000
# unique            NaN
# top               NaN
# freq              NaN
# mean    112012.639200
# std      40306.180338
# ...

# %%
X = dataset.iloc[:,:-1].values
X.shape
# Out:
# (50, 4)

# %%
y = dataset.iloc[:,-1].values
y.shape
# Out:
# (50,)

# %% [markdown]
# ## Missing Data

# %%
dataset[dataset.isna().sum(axis=1)>0]
# Out:
# Empty DataFrame
# Columns: [R&D Spend, Administration, Marketing Spend, State, Profit]
# Index: []

# %% [markdown]
# ## Encoding

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

# %%
# Encoding independent categorical variables
ct = ColumnTransformer(transformers=[('encoder',OneHotEncoder(),[3])],
                       remainder='passthrough')
X = ct.fit_transform(X)

# %%
# Avoiding the dummy variable trap
X = X[:,1:]

# %% [markdown]
# ## Train test split

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=0)

# %% [markdown]
# # Training

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # Predict

# %%
y_pred = regressor.predict(X_test)
plt.scatter(y_test,y_pred)
plt.plot(y_test,y_test)

# %% [markdown]
# # Backward Elimination

# %%
# Import statsmodel
import statsmodels.api as sm

# %%
# Add constant because statsmodel does not add it automatically
X = np.append(arr = np.ones((X.shape[0], 1)).astype(int), values = X, axis = 1)

# %%
X_opt = X[:, [0, 1, 2, 3, 4, 5]]
X_opt = X_opt.astype(np.float64)
regressor_OLS = sm.OLS(endog=y,exog=X_opt).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.951
# Model:                            OLS   Adj. R-squared:                  0.945
# Method:                 Least Squares   F-statistic:                     169.9
# Date:                Sat, 05 Oct 2024   Prob (F-statistic):           1.34e-27
# Time:                        11:08:41   Log-Likelihood:                -525.38
# No. Observations:                  50   AIC:                             1063.
# Df Residuals:                      44   BIC:                             1074.
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       5.013e+04   6884.820      7.281      0.000    3.62e+04     6.4e+04
# ...

# %% [markdown]
# From the report we can see that the variable with the highest P value is variable number 2, that's the one that is eliminated.

# %%
X_opt = X[:, [0, 1, 3, 4, 5]]
X_opt = X_opt.astype(np.float64)
regressor_OLS = sm.OLS(endog = y, exog = X_opt).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.951
# Model:                            OLS   Adj. R-squared:                  0.946
# Method:                 Least Squares   F-statistic:                     217.2
# Date:                Sat, 05 Oct 2024   Prob (F-statistic):           8.49e-29
# Time:                        13:30:23   Log-Likelihood:                -525.38
# No. Observations:                  50   AIC:                             1061.
# Df Residuals:                      45   BIC:                             1070.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       5.011e+04   6647.870      7.537      0.000    3.67e+04    6.35e+04
# ...

# %% [markdown]
# Next, variable number 1 is the one with the highest P value so it's eliminated

# %%
X_opt = X[:, [0, 3, 4, 5]]
X_opt = X_opt.astype(np.float64)
regressor_OLS = sm.OLS(endog = y, exog = X_opt).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.951
# Model:                            OLS   Adj. R-squared:                  0.948
# Method:                 Least Squares   F-statistic:                     296.0
# Date:                Sat, 05 Oct 2024   Prob (F-statistic):           4.53e-30
# Time:                        13:30:53   Log-Likelihood:                -525.39
# No. Observations:                  50   AIC:                             1059.
# Df Residuals:                      46   BIC:                             1066.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       5.012e+04   6572.353      7.626      0.000    3.69e+04    6.34e+04
# ...

# %% [markdown]
# Next, variable with number 2 is eliminated.

# %%
X_opt = X[:, [0, 3, 4, 5]]
X_opt = X_opt.astype(np.float64)
regressor_OLS = sm.OLS(endog = y, exog = X_opt).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.951
# Model:                            OLS   Adj. R-squared:                  0.948
# Method:                 Least Squares   F-statistic:                     296.0
# Date:                Sat, 05 Oct 2024   Prob (F-statistic):           4.53e-30
# Time:                        13:31:27   Log-Likelihood:                -525.39
# No. Observations:                  50   AIC:                             1059.
# Df Residuals:                      46   BIC:                             1066.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       5.012e+04   6572.353      7.626      0.000    3.69e+04    6.34e+04
# ...

# %% [markdown]
# Variable number 2 is eliminated

# %%
X_opt = X[:, [0, 3, 5]]
X_opt = X_opt.astype(np.float64)
regressor_OLS = sm.OLS(endog = y, exog = X_opt).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.950
# Model:                            OLS   Adj. R-squared:                  0.948
# Method:                 Least Squares   F-statistic:                     450.8
# Date:                Sat, 05 Oct 2024   Prob (F-statistic):           2.16e-31
# Time:                        13:31:55   Log-Likelihood:                -525.54
# No. Observations:                  50   AIC:                             1057.
# Df Residuals:                      47   BIC:                             1063.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       4.698e+04   2689.933     17.464      0.000    4.16e+04    5.24e+04
# ...

# %% [markdown]
# variable number 2 is removed

# %%
X_opt = X[:, [0, 3]]
X_opt = X_opt.astype(np.float64)
regressor_OLS = sm.OLS(endog = y, exog = X_opt).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.947
# Model:                            OLS   Adj. R-squared:                  0.945
# Method:                 Least Squares   F-statistic:                     849.8
# Date:                Sat, 05 Oct 2024   Prob (F-statistic):           3.50e-32
# Time:                        13:34:15   Log-Likelihood:                -527.44
# No. Observations:                  50   AIC:                             1059.
# Df Residuals:                      48   BIC:                             1063.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       4.903e+04   2537.897     19.320      0.000    4.39e+04    5.41e+04
# ...

# %% [markdown]
# No more variables are removed
